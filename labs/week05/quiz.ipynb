# %% [markdown]
# # Lab 5.0 Data Structure
#
# ***

# %% [markdown]
# ![Quiz](attachment:image.png)

# %% [markdown]
# ## Answers

# %% [markdown]
# a = int
# b = float
# c = boolean
# d = str
# e = list
# f = tuple
# g = str
# h = dict
# i = list
# j = boolean
# k = dict
# l = str
# m = dict
# n = list
# o = int
# p = str / undefined as there is a typo courseName
#
# 15/16
